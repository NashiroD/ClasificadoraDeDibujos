# %% [markdown]
# <a href="https://colab.research.google.com/github/NashiroD/ClasificadoraDeDibujos/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
cd Dibujos/
# Out:
# /content/Dibujos

# %%
# !ls -l -a
# Out:
# total 40
# drwxr-xr-x 4 root root  4096 Oct 13 16:33 .
# drwxr-xr-x 1 root root  4096 Oct 13 18:37 ..
# drwxr-xr-x 2 root root 20480 Oct 13 16:33 Adulto
# drwxr-xr-x 2 root root 12288 Oct 13 18:09 Nino

# %%
rmdir .ipynb_checkpoints
# Out:
# rmdir: failed to remove '.ipynb_checkpoints': No such file or directory

# %%
# !ls -l -a
# Out:
# total 40
# drwxr-xr-x 4 root root  4096 Oct 13 16:33 .
# drwxr-xr-x 1 root root  4096 Oct 13 18:37 ..
# drwxr-xr-x 2 root root 20480 Oct 13 16:33 Adulto
# drwxr-xr-x 2 root root 12288 Oct 13 18:09 Nino

# %%
cd ..
# Out:
# /content

# %% [markdown]
# Filtrar imagenes corruptas

# %%
import os

num_skipped = 0
for folder_name in ("Adulto", "Nino"):
    folder_path = os.path.join("Dibujos", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            # Delete corrupted image
            os.remove(fpath)

print("Deleted %d images" % num_skipped)
# Out:
# Deleted 0 images

# %% [markdown]
# Generar el Dataset

# %%
image_size = (180, 180)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "Dibujos",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "Dibujos",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 392 files belonging to 2 classes.
# Using 314 files for training.
# Found 392 files belonging to 2 classes.
# Using 78 files for validation.

# %% [markdown]
# Visualizar los datos

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
augmented_train_ds = train_ds.map(
  lambda x, y: (data_augmentation(x, training=True), y))

# %%
train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)

# %% [markdown]
# Build a model

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    x = layers.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=2)
keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# Entrenar el modelo

# %%
epochs = 75

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_model.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
)
# Out:
# Epoch 1/75
# 10/10 [==============================] - 82s 8s/step - loss: 0.1012 - accuracy: 0.9650 - val_loss: 1.4755 - val_accuracy: 0.5769
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch
# Epoch 59/75
# 10/10 [==============================] - 91s 9s/step - loss: 0.0319 - accuracy: 0.9904 - val_loss: 0.1635 - val_accuracy: 0.9744
# Epoch 60/75
# 10/10 [==============================] - 88s 9s/step - loss: 0.0145 - accuracy: 0.9936 - val_loss: 1.0252 - val_accuracy: 0.8462
# Epoch 61/75
# 10/10 [==============================] - 90s 9s/step - loss: 0.0219 - accuracy: 0.9936 - val_loss: 0.4646 - val_accuracy: 0.9231
# Epoch 62/75
# 10/10 [==============================] - 91s 9s/step - loss: 0.0085 - accuracy: 0.9968 - val_loss: 0.5209 - val_accuracy: 0.9487
# Epoch 63/75
# 10/10 [==============================] - 91s 9s/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.4081 - val_accuracy: 0.9487
# Epoch 64/75
# 10/10 [==============================] - 90s 9s/step - loss: 0.0282 - accuracy: 0.9904 - val_loss: 0.1184 - val_accuracy: 0.9872
# Epoch 65/75
# 10/10 [==============================] - 80s 8s/step - loss: 0.0142 - accuracy: 0.9936 - val_loss: 0.6578 - val_accuracy: 0.8974
# Epoch 66/75
# 10/10 [==============================] - 79s 8s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.0507 - val_accuracy: 0.8718
# Epoch 67/75
# 10/10 [==============================] - 79s 8s/step - loss: 0.0267 - accuracy: 0.9904 - val_loss: 0.1946 - val_accuracy: 0.9359
# Epoch 68/75
# 10/10 [==============================] - 79s 8s/step - loss: 0.0294 - accuracy: 0.9904 - val_loss: 0.0210 - val_accuracy: 0.9872
# Epoch 69/75
# 10/10 [==============================] - 79s 8s/step - loss: 0.0145 - accuracy: 0.9904 - val_loss: 0.2552 - val_accuracy: 0.9487
# Epoch 70/75
# 10/10 [==============================] - 79s 8s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4709 - val_accuracy: 0.9487
# Epoch 71/75
# 10/10 [==============================] - 79s 8s/step - loss: 0.0135 - accuracy: 0.9968 - val_loss: 0.4076 - val_accuracy: 0.9487
# Epoch 72/75
# 10/10 [==============================] - 79s 8s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2590 - val_accuracy: 0.9487
# Epoch 73/75
# 10/10 [==============================] - 79s 8s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1731 - val_accuracy: 0.9872
# Epoch 74/75
# 10/10 [==============================] - 79s 8s/step - loss: 0.0051 - accuracy: 0.9968 - val_loss: 0.1139 - val_accuracy: 0.9872
# Epoch 75/75
# 10/10 [==============================] - 79s 8s/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 0.1357 - val_accuracy: 0.9872

# %% [markdown]
# Test

# %%
img = keras.preprocessing.image.load_img(
    "/content/Dibujos/Nino/2008.jpg", target_size=image_size
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
score = predictions[0]
print(
    "This image is %.2f percent Adulto and %.2f percent Niño."
    % (100 * (1 - score), 100 * score)
)
# Out:
# This image is 0.00 percent Adulto and 100.00 percent Niño.
